# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv', ',')
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2  G3
# 0      4        3      4     1     1      3        6  5  6   6
# 1      5        3      3     1     1      3        4  5  5   6
# 2      4        3      2     2     3      3       10  7  8  10
#
# [3 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
column_name = list(df.columns)
print(column_name.index('school'))
print(column_name.index('guardian'))

df = df.iloc[:, range(column_name.index('school'), column_name.index('guardian') + 1)]
df.head(3)
# Out:
# 0
# 11
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home    other
# 2     GP   F   15       U     LE3       T     1     1  at_home    other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother

# %% [markdown]
# ### Step 5. Create a lambda function that capitalize strings.

# %%
df.Mjob = df.Mjob.apply(lambda x: x.upper())
df.loc[:, ['Mjob', 'Fjob', 'reason', 'guardian']] = df.loc[:, ['Mjob', 'Fjob', 'reason', 'guardian']].apply(lambda x: x.apply(lambda y: y.upper()))
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME  TEACHER
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME    OTHER
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME    OTHER
#
#    reason guardian
# 0  COURSE   MOTHER
# 1  COURSE   FATHER
# 2   OTHER   MOTHER

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  \
# 394     MS   M   19       U     LE3       T     1     1  OTHER  AT_HOME
#
#      reason guardian
# 394  COURSE   FATHER

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(x):
    return True if x > 17 else False

df['legal_drinker'] = df.age.apply(majority)
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME  TEACHER
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME    OTHER
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME    OTHER
#
#    reason guardian  legal_drinker
# 0  COURSE   MOTHER           True
# 1  COURSE   FATHER          False
# 2   OTHER   MOTHER          False

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df.loc[:, ['age', 'Medu', 'Fedu']] = df.loc[:, ['age', 'Medu', 'Fedu']].apply(lambda x: x.apply(lambda y: y * 10))
df.head(10)
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F  1800       U     GT3       A   400   400   AT_HOME   TEACHER
# 1     GP   F  1700       U     GT3       T   100   100   AT_HOME     OTHER
# 2     GP   F  1500       U     LE3       T   100   100   AT_HOME     OTHER
# 3     GP   F  1500       U     GT3       T   400   200    HEALTH  SERVICES
# 4     GP   F  1600       U     GT3       T   300   300     OTHER     OTHER
# 5     GP   M  1600       U     LE3       T   400   300  SERVICES     OTHER
# 6     GP   M  1600       U     LE3       T   200   200     OTHER     OTHER
# 7     GP   F  1700       U     GT3       A   400   400     OTHER   TEACHER
# 8     GP   M  1500       U     LE3       A   300   200  SERVICES     OTHER
# 9     GP   M  1500       U     GT3       T   300   400     OTHER     OTHER
#
#        reason guardian  legal_drinker
# 0      COURSE   MOTHER           True
# 1      COURSE   FATHER          False
# 2       OTHER   MOTHER          False
# 3        HOME   MOTHER          False
# 4        HOME   FATHER          False
# 5  REPUTATION   MOTHER          False
# 6        HOME   MOTHER          False
# 7        HOME   MOTHER          False
# 8        HOME   MOTHER          False
# 9        HOME   MOTHER          False

# %%
trial = df.applymap(lambda x: 10 * x if isinstance(x, int) else x)
trial.head(3)
# Out:
#   school sex    age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F  18000       U     GT3       A  4000  4000  AT_HOME  TEACHER
# 1     GP   F  17000       U     GT3       T  1000  1000  AT_HOME    OTHER
# 2     GP   F  15000       U     LE3       T  1000  1000  AT_HOME    OTHER
#
#    reason guardian  legal_drinker
# 0  COURSE   MOTHER             10
# 1  COURSE   FATHER              0
# 2   OTHER   MOTHER              0
